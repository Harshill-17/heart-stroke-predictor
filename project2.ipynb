# %% [markdown]
# **Importing Libraries**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('heart.csv')

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# # EDA & Data Cleaning

# %%
df.shape
# Out:
# (918, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# now i want to predict on the HeartDisease so i'll use the value_counts()
df['HeartDisease'] .value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
df['HeartDisease'] .value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='HeartDisease'>

# %% [markdown]
# ploting the Numarical Columns that have different numerical values

# %%
def plotting(var, num):
    plt.subplot(2, 2, num)  
    sns.histplot(df[var], kde=True)
    plt.title(var) 

# Set figure size
plt.figure(figsize=(12, 8))

# Plot variables
plotting('Age', 1)
plotting('RestingBP', 2)
plotting('Cholesterol', 3)
plotting('MaxHR', 4)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# one thing i'll found out to this plots that a person who dont have RestingBP 0 nd the Cholesterol Level 0 but in my data it has. let me show you

# %%
df['Cholesterol'].value_counts()
# Out:
# Cholesterol
# 0      172
# 254     11
# 220     10
# 223     10
# 204      9
#       ...
# 353      1
# 278      1
# 157      1
# 176      1
# 131      1
# Name: count, Length: 222, dtype: int64

# %% [markdown]
# i need to fix that so i'll be fix with the mean of the remaining people = 918 - 172 = 746 peoples
#
# and replace the 0 values with the mean

# %%
ch_mean = df.loc[df['Cholesterol'] != 0, 'Cholesterol'].mean()

# %%
ch_mean
# Out:
# np.float64(244.6353887399464)

# %%
df['Cholesterol'] = df['Cholesterol'].replace(0, ch_mean)
df['Cholesterol'] = df['Cholesterol'].round(2)

# %%
resting_bp_mean = df.loc[df['RestingBP'] != 0, 'RestingBP'].mean()

df['RestingBP'] = df['RestingBP'].replace(0, resting_bp_mean)
df['RestingBP'] = df['RestingBP'].round(2)

# %%
def plotting(var, num):
    plt.subplot(2, 2, num)  
    sns.histplot(df[var], kde=True)
    plt.title(var) 

# Set figure size
plt.figure(figsize=(12, 8))

# Plot variables
plotting('Age', 1)
plotting('RestingBP', 2)
plotting('Cholesterol', 3)
plotting('MaxHR', 4)

# Adjust layout
plt.tight_layout()
plt.show()

# %%
sns.countplot(x = df['Sex'], hue= df['HeartDisease'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x = df['ChestPainType'], hue= df['HeartDisease'])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.countplot(x = df['FastingBS'], hue= df['HeartDisease'])
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %%
sns.boxplot(x= 'HeartDisease', y='Cholesterol', data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %%
sns.violinplot(x='HeartDisease', y='Age', data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Data Preprocessing & Data Cleaning

# %%
df_encode = pd.get_dummies(df, drop_first=True)
df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40      140.0        289.0          0    172      0.0             0
# 1     49      160.0        180.0          0    156      1.0             1
# 2     37      130.0        283.0          0     98      0.0             0
# 3     48      138.0        214.0          0    108      1.5             1
# 4     54      150.0        195.0          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45      110.0        264.0          0    132      1.2             1
# 914   68      144.0        193.0          1    141      3.4             1
# 915   57      130.0        131.0          0    115      1.2             1
# 916   57      130.0        236.0          0    174      0.0             1
# 917   38      138.0        175.0          0    173      0.0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
df_encode = df_encode.astype(int)

df_encode
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172        0             0
# 1     49        160          180          0    156        1             1
# 2     37        130          283          0     98        0             0
# 3     48        138          214          0    108        1             1
# 4     54        150          195          0    122        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132        1             1
# 914   68        144          193          1    141        3             1
# 915   57        130          131          0    115        1             1
# 916   57        130          236          0    174        0             1
# 917   38        138          175          0    173        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %%
df_encode.columns
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'HeartDisease', 'Sex_M', 'ChestPainType_ATA', 'ChestPainType_NAP',
#        'ChestPainType_TA', 'RestingECG_Normal', 'RestingECG_ST',
#        'ExerciseAngina_Y', 'ST_Slope_Flat', 'ST_Slope_Up'],
#       dtype='object')

# %% [markdown]
# **Importing some Libraries**

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.linear_model import LinearRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# **Dividing Data into x and y labels**

# %%
X = df_encode.drop('HeartDisease', axis=1) # without the HearDisease all the Columns
y = df_encode['HeartDisease']

X
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  Sex_M  \
# 0     40        140          289          0    172        0      1
# 1     49        160          180          0    156        1      0
# 2     37        130          283          0     98        0      1
# 3     48        138          214          0    108        1      0
# 4     54        150          195          0    122        0      1
# ..   ...        ...          ...        ...    ...      ...    ...
# 913   45        110          264          0    132        1      1
# 914   68        144          193          1    141        3      1
# 915   57        130          131          0    115        1      1
# 916   57        130          236          0    174        0      0
# 917   38        138          175          0    173        0      1
#
#      ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# 0                    1                  0                 0
# ...

# %% [markdown]
# **A little-bit Train-Test Split for the Model**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %% [markdown]
# **Feature Scaling**

# %%
scaler = StandardScaler()
x_train_scaled = scaler.fit_transform(X_train)
x_test_scaled = scaler.fit_transform(X_test)

# %% [markdown]
# - now i get the Two Datas 1. With Standard Scaler (x_train_scaled & x_test_scaled), 2. Without Standard Scaler (x_train, x_test)

# %% [markdown]
# **Creating Models**

# %%
models = {
    "Logistic Regression" : LinearRegression(),
    "KNN" : KNeighborsClassifier(),
    "Naive Byeas" : GaussianNB(),
    "Decision Tree" : DecisionTreeClassifier(),
    "SVM" : SVC()
}

# %%
result = [] # to store the models results

# %% [markdown]
# **With the Use of the loop go through all the models in the Dict**

# %%
for name, model in models.items() :
    model.fit(x_train_scaled, y_train)
    y_pred = model.predict(x_test_scaled)
    
    if y_pred.ndim == 1 and np.issubdtype(y_pred.dtype, np.floating):
        y_pred = (y_pred >= 0.5).astype(int)
        
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    result.append({
        'Model' : name,
        'Accuracy' : round(acc, 4),
        'F1 Score' : round(f1, 2)
    })

# %%
result
# Out:
# [{'Model': 'Logistic Regression', 'Accuracy': 0.8587, 'F1 Score': 0.88},
#  {'Model': 'KNN', 'Accuracy': 0.8641, 'F1 Score': 0.88},
#  {'Model': 'Naive Byeas', 'Accuracy': 0.8533, 'F1 Score': 0.87},
#  {'Model': 'Decision Tree', 'Accuracy': 0.7663, 'F1 Score': 0.79},
#  {'Model': 'SVM', 'Accuracy': 0.8478, 'F1 Score': 0.87}]

# %% [markdown]
# **Use the KNN Model because the Best Score**

# %% [markdown]
# - Saving that models into the pkl format

# %%
import joblib

joblib.dump(models['KNN'], 'KNN_heart.pkl')
joblib.dump(scaler, 'scaler.pkl')
joblib.dump(X.columns.tolist(), 'columns.pkl')
# Out:
# ['columns.pkl']
